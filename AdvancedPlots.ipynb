# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from PIL.ImageColor import colormap
from matplotlib.pyplot import xticks
# %matplotlib inline

# %%
import datetime
#Import data
nasa = pd.read_csv("data/data/nasa_facebook_statuses.csv",
usecols=["status_published","num_reactions",
"num_comments","num_shares","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published']
< '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)
#Remove non-numeric column
nasa.drop('status_published', axis=1, inplace=True)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day['num_shares'].plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day[['num_shares','num_comments']].plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day.plot(y=['num_shares','num_comments'])
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# # Parameters in plot method

# %%
import datetime
#Import data
nasa = pd.read_csv("data/data/nasa_facebook_statuses.csv",
usecols=["status_published","num_reactions",
"num_comments","num_shares","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=
1)
#Remove column with status_published - we don't need it anymore
nasa.drop('status_published', axis='columns', inplace=True)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity')
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',subplots=True)
# Out:
# array([<Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>], dtype=object)

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',logy=True)
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',xticks=range(1,32))
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',xticks=range(1,32),rot=45)
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day[:10].plot(figsize=(15,5),title='NASA Facebook activity',table=True)
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %% [markdown]
# # Formatting plot

# %%
import datetime
#Import data
nasa = pd.read_csv("data/data/nasa_facebook_statuses.csv",
usecols=["status_published","num_reactions",
"num_comments","num_shares","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)
nasa.drop('status_published', axis='columns', inplace=True)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity')
# Out:
# <Axes: title={'center': 'NASA Facebook acitivty'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',color=('r','g','b','k'))
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',colormap='spring')
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',colormap='autumn')
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
plt.style.use('fivethirtyeight')

# %%
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',colormap='autumn')
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
plt.style.use('dark_background')
nasa_by_day.plot(figsize=(15,5),title='NASA Facebook activity',colormap='autumn')
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %% [markdown]
# # Pie chart

# %%
import datetime
#Import data
nasa = pd.read_csv("data/data/nasa_facebook_statuses.csv",
usecols=["status_published","num_reactions",
"num_comments","num_shares","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-3-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['month'] = nasa.apply(lambda row: row["status_published"].month,axis
=1)
#Group all columns by sum
nasa.drop('status_published', axis='columns', inplace=True)
nasa_by_month = nasa.groupby(by='month').sum()
nasa_by_month.head()
# Out:
#        num_reactions  num_comments  num_shares  num_likes
# month
# 3            3003815         49108      392585    2846361
# 4            2927616        120118      370803    2760385
# 5            2708977         46122      393576    2548960

# %%
nasa_by_month['num_likes'].plot(kind='pie')
# Out:
# <Axes: ylabel='num_likes'>

# %%
nasa_by_month['num_likes'].plot(kind='pie',figsize=(5,5),title='NASA Facebook activity',labels=('March','April','June'))
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, ylabel='num_likes'>

# %%
nasa_by_month.plot(kind='pie',figsize=(5,5),title='NASA Facebook activity',labels=('March','April','June'),subplots=True)
# Out:
# array([<Axes: ylabel='num_reactions'>, <Axes: ylabel='num_comments'>,
#        <Axes: ylabel='num_shares'>, <Axes: ylabel='num_likes'>],
#       dtype=object)

# %%
nasa_by_month.plot(kind='pie',figsize=(10,10 ),title='NASA Facebook activity',layout=(2,2),subplots=True)
# Out:
# array([[<Axes: ylabel='num_reactions'>, <Axes: ylabel='num_comments'>],
#        [<Axes: ylabel='num_shares'>, <Axes: ylabel='num_likes'>]],
#       dtype=object)

# %%
nasa_by_month.plot(kind="pie", figsize=(10,10),
labels=("March","April","June"),
title="NASA Facebook activity",
subplots=True,
layout=(2,2), legend=True,
autopct="%.0f%%", textprops=dict(color='black'))
# Out:
# array([[<Axes: ylabel='num_reactions'>, <Axes: ylabel='num_comments'>],
#        [<Axes: ylabel='num_shares'>, <Axes: ylabel='num_likes'>]],
#       dtype=object)

# %% [markdown]
# # Bar, hist and box plots

# %%
marathon = pd.read_csv("data/data/marathon_results_2017.csv", usecols=["Age","M/F","Country","40K"])
marathon["TimeSeconds"] = pd.to_timedelta(marathon["40K"], errors='coerce').dt.total_seconds()
groupMF = marathon[ marathon["Country"].isin(["USA","CAN"])].groupby(by=["Country","M/F"])
groupMF = groupMF.agg({"TimeSeconds": ["mean"]})
groupMF = groupMF.unstack()
groupMF.columns = groupMF.columns.droplevel().droplevel()
groupMF
# Out:
# M/F                 F             M
# Country
# CAN      13618.346012  12527.160190
# USA      14188.759649  13004.157656

# %%
groupMF.plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
groupMF.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Country'>

# %%
groupMF.plot(kind='barh')
# Out:
# <Axes: ylabel='Country'>

# %%
age_data = marathon[marathon["Country"].isin(["USA"])]
age_data.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 1   30   M     USA  2:03:14       7394.0
# 3   32   M     USA  2:04:35       7475.0
# 5   40   M     USA  2:05:21       7521.0
# 6   33   M     USA  2:05:41       7541.0
# 8   27   M     USA  2:07:17       7637.0

# %%
age_data['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
age_data['Age'].nunique()
# Out:
# 66

# %%
age_data['Age'].plot(kind='hist',bins=66)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_USA = marathon[ marathon["Country"].isin(["USA"]) ]
data_USA.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 1   30   M     USA  2:03:14       7394.0
# 3   32   M     USA  2:04:35       7475.0
# 5   40   M     USA  2:05:21       7521.0
# 6   33   M     USA  2:05:41       7541.0
# 8   27   M     USA  2:07:17       7637.0

# %%
data_USA['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
USA = marathon[ marathon["Country"].isin(["USA"]) ]["Age"]
CAN = marathon[ marathon["Country"].isin(["CAN"]) ]["Age"]
df = pd.DataFrame({'USA':USA, 'CAN':CAN})
df.head()
# Out:
#     USA  CAN
# 1  30.0  NaN
# 3  32.0  NaN
# 5  40.0  NaN
# 6  33.0  NaN
# 8  27.0  NaN

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Scatter, hexbin and area plots

# %%
marathon = pd.read_csv("data/data/marathon_results_2017.csv", usecols=["Age","M/F","Country","40K"])
marathon = marathon[(marathon['40K'] != '-') ]
marathon["TimeSeconds"] = marathon["40K"].apply(lambda x: pd.Timedelta(x).total_seconds())
marathon.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 0   24   M     KEN  2:02:53       7373.0
# 1   30   M     USA  2:03:14       7394.0
# 2   25   M     JPN  2:03:38       7418.0
# 3   32   M     USA  2:04:35       7475.0
# 4   31   M     KEN  2:05:00       7500.0

# %%
marathon.plot(kind="scatter", x="Age", y="TimeSeconds")
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_m = marathon[marathon['M/F']=='M']

# %%
marathon_f = marathon[marathon['M/F']=='F']

# %%
ax = marathon_m.plot.scatter(x='Age',y='TimeSeconds',color='Blue',label="M")
marathon_f.plot.scatter(x='Age',y='TimeSeconds',color='Pink',ax=ax)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_m.plot.hexbin(x='Age',y='TimeSeconds',gridsize=30)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
import datetime
#Import data
nasa = pd.read_csv("data/data/nasa_facebook_statuses.csv",
usecols=["status_published","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum(numeric_only=True)

# %%
#Import data
bean = pd.read_csv("data/data/mrbean_facebook_statuses.csv",
usecols=["status_published","num_likes"])
#Convert column type to date time
bean["status_published"] = pd.to_datetime(bean["status_published"])
#Select observations between two datetimes - May 2015
filter =(bean['status_published'] >= '2016-5-1') & (bean['status_published'] < '2016-6-1')
bean = bean[filter]
#Add column with day only
bean['day'] = bean.apply(lambda row: row["status_published"].day,axis=1)
#Group all columns by sum
bean_by_day = bean.groupby(by='day').sum(numeric_only=True)
days = pd.concat([nasa["day"], bean["day"]])
days = days.unique()
fb = pd.DataFrame(index=days).sort_index()
fb['nasa'] = nasa_by_day["num_likes"]
fb['bean'] = bean_by_day["num_likes"]
fb.fillna(value=0, inplace=True)
fb.head()
# Out:
#      nasa     bean
# 1   60243      0.0
# 2  177989      0.0
# 3   50264      0.0
# 4  133302  26821.0
# 5   89657      0.0

# %%
fb.plot.area()
# Out:
# <Axes: >
